# %%
from data_creation import data_creation, pickle_me, get_pickle

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### add your directory path for the images here

# %%
data_dir = 'C://Users/Cristian/Desktop/Math stuff/Data/'
categories = ['glass', 'metal', 'paper', 'plastic']

# %% [markdown]
# # To make data

# %%
X_grayscale, y_grayscale = data_creation(100,0,categories,data_dir)

# %%
X_color, y_color = data_creation(100, 1, categories, data_dir)

# %% [markdown]
# # To export data

# %%
pickle_me(X_grayscale, y_grayscale, 'X_grayscale', 'y_grayscale')
pickle_me(X_color, y_color, 'X_color', 'y_color')

# %% [markdown]
# # To import data

# %%
X_gray, y_gray = get_pickle('X_grayscale.pickle', 'y_grayscale.pickle')
X_col, y_col = get_pickle('X_color.pickle', 'y_color.pickle')

# %% [markdown]
# # Getting the first image from each set to show how they look
# They are going to be different since the data gets shuffled around when the sets are

# %%
for img in X_gray:
    img = img.reshape(100,100)
    plt.imshow(img, cmap='gray')
    break

# %%
for img in X_col:
    img = img.reshape(100,100,3)
    plt.imshow(img)
    break
